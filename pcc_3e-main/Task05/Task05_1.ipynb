# %%
num_list = [2, 1, 6]

def solution(num_list):
    answer = []
    
    return answer

# %%
last = num_list[-1]
# Out:
# 6

# %%
pre = num_list[-2]
# Out:
# 1

# %%
num_list = [2, 1, 6]

def solution(num_list):
    last = num_list[-1]
    pre = num_list[-2]
    
    if last > pre :
        num_list.append(last - pre)
    else :
        num_list.append(last * 2)
    
    return num_list

print(solution(num_list))
# Out:
# [2, 1, 6, 5]
