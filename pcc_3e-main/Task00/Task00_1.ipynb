# %%
a = 9 ;
b = 91;

def solution(a, b):
    answer = 0
    i = int(str(a) + str(b));
    j = int(str(b) + str(a));
    
    print(f"i = a ⊕ b = {i}")
    print(f"j = b ⊕ a = {j}")
    return max(i, j)

print("solution",solution(a, b))



    # if i > j :
    #     answer = i;
    #     print(answer)
        
    #     return answer
    # else :
    #     answer = j;
    #     print(answer)
    #     return answer
# Out:
# i = a ⊕ b = 991
# j = b ⊕ a = 919
# solution 991

# %%
for i in range(1, n+1):
