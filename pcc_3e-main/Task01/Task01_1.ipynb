# %%
1+2
# Out:
# 3

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
d = True
d, type(d)
# Out:
# (True, bool)

# %%
e = []
e, type(d)
# Out:
# ([], bool)

# %%
f = ()
f, type(f)
# Out:
# ((), tuple)

# %%
g = {}
g, type(g)
# Out:
# ({}, dict)

# %%
1/2
# Out:
# 0.5

# %%
s = "hello"

# %%
s+ " world"
# Out:
# 'hello world'

# %%
type(s)
# Out:
# str

# %%
s.capitalize()
# Out:
# 'Hello'

# %%
s1 = s+ " world"
s1.title()
# Out:
# 'Hello World'

# %%
s = "hello"
s[0] , s[1], s[2]
# Out:
# ('h', 'e', 'l')

# %%
s = "hello"
s[-1]
# Out:
# 'o'

# %%
s[-1], s[1:-1], s[:2], s[2:]
# Out:
# ('o', 'ell', 'he', 'llo')

# %%
# s = 'aba'
# s == s[::-1] 
s = 'hello'
s[::-1] #뒤집어서 출력
# Out:
# 'olleh'

# %%
s = "hello"
for i in s:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
s = "hello"
s + " world"
# Out:
# 'hello world'

# %%
'e' in s
# Out:
# True

# %%
'a' in 'hello', 'e' in 'hello'
# Out:
# (False, True)

# %%
s = "hello"
def count_vowel(s):
    count=0
    vowels = 'aeiou'
    for i in s:
        if i in vowels:
            count += 1
    return count

count_vowel(s)
# Out:
# 2

# %%
a = [1,2,3,4,5]
a + [6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for i in [3,2,1]:
    print('*' * i)
# Out:
# ***
# **
# *

# %% [markdown]
# ## String

# %%
a = 5
b = 3.14
print("{}, {:.2f}".format(a, b))
# Out:
# 5, 3.14

# %%
stack = []

def push(e):
    stack.insert(0,e)

    push(1)
    push(2)
    push(3)

stack
# Out:
# []

# %%
def pop():
    return stack.pop

# %%
l = [3,2,1]
