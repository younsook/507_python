# %%
1+2
# Out:
# 3

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
d = True
d, type(d)
# Out:
# (True, bool)

# %%
e = []
e, type(d)
# Out:
# ([], bool)

# %%
f = ()
f, type(f)
# Out:
# ((), tuple)

# %%
g = {}
g, type(g)
# Out:
# ({}, dict)

# %%
1/2
# Out:
# 0.5

# %%
s = "hello"

# %%
s+ " world"
# Out:
# 'hello world'

# %%
type(s)
# Out:
# str

# %%
s.capitalize()
# Out:
# 'Hello'

# %%
s1 = s+ " world"
s1.title()
# Out:
# 'Hello World'

# %%
s = "hello"
s[0] , s[1], s[2]
# Out:
# ('h', 'e', 'l')

# %%
s = "hello"
s[-1]
# Out:
# 'o'

# %%
s[-1], s[1:-1], s[:2], s[2:]
# Out:
# ('o', 'ell', 'he', 'llo')

# %%
# s = 'aba'
# s == s[::-1] 
s = 'hello'
s[::-1] #뒤집어서 출력
# Out:
# 'olleh'

# %%
s = "hello"
for i in s:
    print(i)
# Out:
# h
# e
# l
# l
# o
